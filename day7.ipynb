# %% [markdown]
# <a href="https://colab.research.google.com/github/zahra-sharifzadeh/100daysPythonBootcamp/blob/main/day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Hangman_1_start

# %%
import random

word_list = ["ardvark", "baboon", "camel"]
check_list = []

chosen_word = random.choice(word_list)

# list_choesn_word = list(chosen_word)

guess = input("guess a letter: ").lower()

for i in chosen_word:
  if i == guess:
    check_list.append("right")

  else:
    check_list.append("wrong")

print(check_list)
# Out:
# guess a letter: e
# ['wrong', 'wrong', 'wrong', 'wrong', 'wrong', 'wrong']

# %% [markdown]
# ## Hangman_2_start

# %%
import random

word_list = ["ardvark", "baboon", "camel"]
check_list = []
word_blank = []
chosen_word = random.choice(word_list)

print(f"the chosen word is: {chosen_word}.")
# list_choesn_word = list(chosen_word)


for i in chosen_word:
  word_blank.append("_")


guess = input("Guess a letter: ").lower()

for i in range(len(chosen_word)):
  if chosen_word[i] == guess:
    word_blank[i] = guess




# for i in chosen_word:
#   if i == guess:
#     check_list.append("right")

#   else:
#     check_list.append("wrong")

print(word_blank)
# Out:
# the chosen word is: baboon.
# Guess a letter: b
# ['b', '_', 'b', '_', '_', '_']

# %% [markdown]
# ## Hangman-3-Start

# %%
import random

word_list = ["ardvark", "baboon", "camel"]
check_list = []
word_blank = []
chosen_word = random.choice(word_list)

print(f"the chosen word is: {chosen_word}.")
# list_choesn_word = list(chosen_word)


for i in chosen_word:
  word_blank.append("_")

while "_" in word_blank:
  guess = input("Guess a letter: ").lower()

  for i in range(len(chosen_word)):
    if chosen_word[i] == guess:
      word_blank[i] = guess

  print(word_blank)

print(word_blank)
# Out:
# the chosen word is: camel.
# Guess a letter: a
# ['_', 'a', '_', '_', '_']
# Guess a letter: c
# ['c', 'a', '_', '_', '_']
# Guess a letter: m
# ['c', 'a', 'm', '_', '_']
# Guess a letter: e
# ['c', 'a', 'm', 'e', '_']
# Guess a letter: l
# ['c', 'a', 'm', 'e', 'l']
# ['c', 'a', 'm', 'e', 'l']

# %%
word_list = [
'abruptly',
'absurd',
'abyss',
'affix',
'askew',
'avenue',
'awkward',
'axiom',
'azure',
'bagpipes',
'bandwagon',
'banjo',
'bayou',
'beekeeper',
'bikini',
'blitz',
'blizzard',
'boggle',
'bookworm',
'boxcar',
'boxful',
'buckaroo',
'buffalo',
'buffoon',
'buxom',
'buzzard',
'buzzing',
'buzzwords',
'caliph',
'cobweb',
'cockiness',
'croquet',
'crypt',
'curacao',
'cycle',
'daiquiri',
'dirndl',
'disavow',
'dizzying',
'duplex',
'dwarves',
'embezzle',
'equip',
'espionage',
'euouae',
'exodus',
'faking',
'fishhook',
'fixable',
'fjord',
'flapjack',
'flopping',
'fluffiness',
'flyby',
'foxglove',
'frazzled',
'frizzled',
'fuchsia',
'funny',
'gabby',
'galaxy',
'galvanize',
'gazebo',
'giaour',
'gizmo',
'glowworm',
'glyph',
'gnarly',
'gnostic',
'gossip',
'grogginess',
'haiku',
'haphazard',
'hyphen',
'iatrogenic',
'icebox',
'injury',
'ivory',
'ivy',
'jackpot',
'jaundice',
'jawbreaker',
'jaywalk',
'jazziest',
'jazzy',
'jelly',
'jigsaw',
'jinx',
'jiujitsu',
'jockey',
'jogging',
'joking',
'jovial',
'joyful',
'juicy',
'jukebox',
'jumbo',
'kayak',
'kazoo',
'keyhole',
'khaki',
'kilobyte',
'kiosk',
'kitsch',
'kiwifruit',
'klutz',
'knapsack',
'larynx',
'lengths',
'lucky',
'luxury',
'lymph',
'marquis',
'matrix',
'megahertz',
'microwave',
'mnemonic',
'mystify',
'naphtha',
'nightclub',
'nowadays',
'numbskull',
'nymph',
'onyx',
'ovary',
'oxidize',
'oxygen',
'pajama',
'peekaboo',
'phlegm',
'pixel',
'pizazz',
'pneumonia',
'polka',
'pshaw',
'psyche',
'puppy',
'puzzling',
'quartz',
'queue',
'quips',
'quixotic',
'quiz',
'quizzes',
'quorum',
'razzmatazz',
'rhubarb',
'rhythm',
'rickshaw',
'schnapps',
'scratch',
'shiv',
'snazzy',
'sphinx',
'spritz',
'squawk',
'staff',
'strength',
'strengths',
'stretch',
'stronghold',
'stymied',
'subway',
'swivel',
'syndrome',
'thriftless',
'thumbscrew',
'topaz',
'transcript',
'transgress',
'transplant',
'triphthong',
'twelfth',
'twelfths',
'unknown',
'unworthy',
'unzip',
'uptown',
'vaporize',
'vixen',
'vodka',
'voodoo',
'vortex',
'voyeurism',
'walkway',
'waltz',
'wave',
'wavy',
'waxy',
'wellspring',
'wheezy',
'whiskey',
'whizzing',
'whomever',
'wimpy',
'witchcraft',
'wizard',
'woozy',
'wristwatch',
'wyvern',
'xylophone',
'yachtsman',
'yippee',
'yoked',
'youthful',
'yummy',
'zephyr',
'zigzag',
'zigzagging',
'zilch',
'zipper',
'zodiac',
'zombie',
]

# %%
stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

logo2 = '''
█▀▀ █▀█ █▀█ █▀▄   █░█░█ █▀█ █▀█ █▄▀ █
█▄█ █▄█ █▄█ █▄▀   ▀▄▀▄▀ █▄█ █▀▄ █░█ ▄
'''

logo3 = '''
█░█░█ █▀▀ █░░ █▀▀ █▀█ █▀▄▀█ █▀▀   ▀█▀ █▀█ ▀
▀▄▀▄▀ ██▄ █▄▄ █▄▄ █▄█ █░▀░█ ██▄   ░█░ █▄█ ▄

██╗░░██╗░█████╗░███╗░░██╗░██████╗░███╗░░░███╗░█████╗░███╗░░██╗
██║░░██║██╔══██╗████╗░██║██╔════╝░████╗░████║██╔══██╗████╗░██║
███████║███████║██╔██╗██║██║░░██╗░██╔████╔██║███████║██╔██╗██║
██╔══██║██╔══██║██║╚████║██║░░╚██╗██║╚██╔╝██║██╔══██║██║╚████║
██║░░██║██║░░██║██║░╚███║╚██████╔╝██║░╚═╝░██║██║░░██║██║░╚███║
╚═╝░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝░╚═════╝░╚═╝░░░░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝'''

# %%
import random

print(logo3)

# word_list = ["ardvark", "baboon", "camel"]
check_list = []
word_blank = []
lives = 6
chosen_word = random.choice(word_list)

# print(f"the chosen word is: {chosen_word}.")
# list_choesn_word = list(chosen_word)


for i in chosen_word:
  word_blank.append("_")

while ("_" in word_blank) and lives > -1:
  guess = input("Guess a letter: ").lower()

  for i in range(len(chosen_word)):
    if chosen_word[i] == guess:
      word_blank[i] = guess
      print(word_blank)


  if guess not in chosen_word:
    print(stages[lives])
    lives -= 1
if "_" not in word_blank:
  print(logo2)

print(f"the chosen word is: {chosen_word}.")
# Out:
# █░█░█ █▀▀ █░░ █▀▀ █▀█ █▀▄▀█ █▀▀   ▀█▀ █▀█ ▀
# ▀▄▀▄▀ ██▄ █▄▄ █▄▄ █▄█ █░▀░█ ██▄   ░█░ █▄█ ▄
#
# ██╗░░██╗░█████╗░███╗░░██╗░██████╗░███╗░░░███╗░█████╗░███╗░░██╗
# ██║░░██║██╔══██╗████╗░██║██╔════╝░████╗░████║██╔══██╗████╗░██║
# ███████║███████║██╔██╗██║██║░░██╗░██╔████╔██║███████║██╔██╗██║
# ██╔══██║██╔══██║██║╚████║██║░░╚██╗██║╚██╔╝██║██╔══██║██║╚████║
# ██║░░██║██║░░██║██║░╚███║╚██████╔╝██║░╚═╝░██║██║░░██║██║░╚███║
# ╚═╝░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝░╚═════╝░╚═╝░░░░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝
# Guess a letter: a
# ['_', '_', '_', '_', '_', '_', '_', '_', 'a']
# Guess a letter: e
# ['_', '_', 'e', '_', '_', '_', '_', '_', 'a']
# Guess a letter: b
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# Guess a letter: o
# ['_', '_', 'e', '_', '_', 'o', '_', '_', 'a']
# Guess a letter: i
# ['_', '_', 'e', '_', '_', 'o', '_', 'i', 'a']
# Guess a letter: h
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# Guess a letter: s
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
# ...

# %%
# !pip install pycopy-reprlib
# Out:
# ...
# ERROR: pycopy-reprlib from https://files.pythonhosted.org/packages/07/75/f5e5b2254f44faccb0e02e53780f75510cd6778c7c9d88b2e2547c06f04e/pycopy-reprlib-0.0.1.tar.gz does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
import random
# from reprlib import clear
print(logo3)

# word_list = ["ardvark", "baboon", "camel"]
check_list = []
word_blank = []
lives = 6
chosen_word = random.choice(word_list)

# print(f"the chosen word is: {chosen_word}.")
# list_choesn_word = list(chosen_word)


for i in chosen_word:
  word_blank.append("_")

while ("_" in word_blank) and lives > -1:
  guess = input("Guess a letter: ").lower()

  for i in range(len(chosen_word)):
    if chosen_word[i] == guess:
      word_blank[i] = guess
      print(word_blank)


  if guess not in chosen_word:
    print(stages[lives])
    lives -= 1
if "_" not in word_blank:
  print(logo2)

print(f"the chosen word is: {chosen_word}.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-2aee3953778c> in <cell line: 2>()
#       1 import random
# ----> 2 from reprlib import clear
#       3 print(logo3)
#       4
#       5 # word_list = ["ardvark", "baboon", "camel"]
#
# ImportError: cannot import name 'clear' from 'reprlib' (/usr/lib/python3.10/reprlib.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
